# %% [markdown]
# <a href="https://colab.research.google.com/github/chetan0321/ML_FLASK090/blob/main/ice_cream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
temperature = [15, 18, 22, 25, 28, 30, 32, 35]
ice_cream_sales = [20, 25, 40, 50, 65, 70, 80, 85]


# Create the scatter plot
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(temperature, ice_cream_sales, marker='o', color='skyblue', edgecolor='black')

# Customize the plot
plt.title('Temperature vs. Ice Cream Sales')
plt.xlabel('Temperature (°C)')
plt.ylabel('Ice Cream Sales')
plt.grid(True)

# Show the plot
plt.show()
