# %% [markdown]
# <a href="https://colab.research.google.com/github/chetan0321/ML_FLASK090/blob/main/RecommendationSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file_path='/content/Movie.csv'

# %%
movies_df=pd.read_csv(file_path)

# %%
max=len(movies_df.userId.unique())
movies_df[0:10]
# Out:
#    userId             movie  rating
# 0       3  Toy Story (1995)     4.0
# 1       6  Toy Story (1995)     5.0
# 2       8  Toy Story (1995)     4.0
# 3      10  Toy Story (1995)     4.0
# 4      11  Toy Story (1995)     4.5
# 5      12  Toy Story (1995)     4.0
# 6      13  Toy Story (1995)     4.0
# 7      14  Toy Story (1995)     4.5
# 8      16  Toy Story (1995)     3.0
# 9      19  Toy Story (1995)     5.0

# %%
len(movies_df.userId.unique())
# Out:
# 4081

# %%
len(movies_df.movie.unique())
# Out:
# 10

# %%
user_movies_df = movies_df.pivot(index='userId',columns='movie',values='rating').reset_index(drop=True)

# %%
user_movies_df
# Out:
# movie  Father of the Bride Part II (1995)  GoldenEye (1995)  \
# 0                                     NaN               NaN
# 1                                     NaN               NaN
# 2                                     NaN               NaN
# 3                                     NaN               4.0
# 4                                     NaN               NaN
# ...                                   ...               ...
# 4076                                  4.0               NaN
# 4077                                  3.5               NaN
# 4078                                  NaN               3.0
# 4079                                  NaN               NaN
# 4080                                  NaN               NaN
#
# movie  Grumpier Old Men (1995)  Heat (1995)  Jumanji (1995)  Sabrina (1995)  \
# 0                          NaN          NaN             3.5             NaN
# 1                          4.0          NaN             NaN             NaN
# ...

# %%
user_movies_df.index = movies_df.userId.unique()
user_movies_df
# Out:
# movie  Father of the Bride Part II (1995)  GoldenEye (1995)  \
# 3                                     NaN               NaN
# 6                                     NaN               NaN
# 8                                     NaN               NaN
# 10                                    NaN               4.0
# 11                                    NaN               NaN
# ...                                   ...               ...
# 7044                                  4.0               NaN
# 7070                                  3.5               NaN
# 7080                                  NaN               3.0
# 7087                                  NaN               NaN
# 7105                                  NaN               NaN
#
# movie  Grumpier Old Men (1995)  Heat (1995)  Jumanji (1995)  Sabrina (1995)  \
# 3                          NaN          NaN             3.5             NaN
# 6                          4.0          NaN             NaN             NaN
# ...

# %%
user_movies_df.fillna(0,inplace=True)
user_movies_df
# Out:
# movie  Father of the Bride Part II (1995)  GoldenEye (1995)  \
# 3                                     0.0               0.0
# 6                                     0.0               0.0
# 8                                     0.0               0.0
# 10                                    0.0               4.0
# 11                                    0.0               0.0
# ...                                   ...               ...
# 7044                                  4.0               0.0
# 7070                                  3.5               0.0
# 7080                                  0.0               3.0
# 7087                                  0.0               0.0
# 7105                                  0.0               0.0
#
# movie  Grumpier Old Men (1995)  Heat (1995)  Jumanji (1995)  Sabrina (1995)  \
# 3                          0.0          0.0             3.5             0.0
# 6                          4.0          0.0             0.0             0.0
# ...

# %%
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine, correlation

# %%
from scipy.spatial.distance import cosine, correlation

vec1 = [5,8,4,3]
vec2 = [4,5,3,7]
correlation_distance = correlation(vec1, vec2)
print(correlation_distance)
# Out:
# 1.1807015805810503

# %%
user_sim_df = 1- pairwise_distances( user_movies_df.values,metric='cosine')

# %%
user_sim_df
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.55337157],
#        [0.        , 1.        , 0.        , ..., 0.45883147, 0.        ,
#         0.        ],
#        [0.        , 0.        , 1.        , ..., 0.45883147, 1.        ,
#         0.62254302],
#        ...,
#        [0.        , 0.45883147, 0.45883147, ..., 1.        , 0.45883147,
#         0.47607054],
#        [0.        , 0.        , 1.        , ..., 0.45883147, 1.        ,
#         0.62254302],
#        [0.55337157, 0.        , 0.62254302, ..., 0.47607054, 0.62254302,
#         1.        ]])

# %%
movies_df[movies_df['userId']==5]
# Out:
#       userId           movie  rating
# 2570       5  Jumanji (1995)     3.0

# %%
movies_df[movies_df['userId']==129]
# Out:
#       userId             movie  rating
# 41       129  Toy Story (1995)     4.0
# 2583     129    Jumanji (1995)     3.0

# %%
pd.concat([movies_df[movies_df['userId']==224], movies_df[movies_df['userId']==194]])
# Out:
#       userId             movie  rating
# 7483     224  GoldenEye (1995)     3.0
